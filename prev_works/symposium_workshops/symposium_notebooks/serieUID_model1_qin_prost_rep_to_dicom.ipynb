# %% [markdown]
# # Prostate segmentation on IDC collection -- MRI US Prostate Biopsy
# *   Dataset : [MRI US Prostate Biopsy]()
# *   Goal : Prostate segmentation using Task24 Prostate nnU-net pre-trained model, T2 input

# %% [markdown]
# resample preds to idc image data with .nrrd == LPS orientation instead of RAS == necessary for DICOM conversion of AI segs

# %% [markdown]
# # Global variables

# %% [markdown]
# ## Variables used for resampling -- inference -- setup labelID for ground truth segs

# %%
# IDC collection for paths setup
collection_name = "prostatex" #up to user
##nnunet
model_type = '3d_fullres'#other options are '2d',..
nnunet_labelID = 1 #for task005 model, labelid=1 means PZ and 2 means TZ
# ##labelID seg retrieval
# ground_truth_cat_CodeMeaning = 'Anatomical Structure'
# ground_truth_type_CodeMeaning = 'Peripheral zone of the prostate'
#Resampling scheme -- this option is made for qin-rep-repeatability(SeriesDescription tag dependence,etc), not modular for other collections with multi modal inference input
desired_grid = "T2" #Other option is "ADC"

# %% [markdown]
# ## Global paths

# %%
import os 

#qin_prostate_repeatibility
os.environ["prostatex_root"] = os.path.join(os.getcwd(), "prostateX")
os.environ["prostatex_dicom"] = os.path.join(os.environ["prostatex_root"], "dicom")
os.environ["prostatex_nii"] = os.path.join(os.environ["prostatex_root"], "nii")

#nnunet
os.environ["nnUNet"] = os.path.join(os.getcwd(), "nnUNet")
os.environ["nnUNet_data"] = os.path.join(os.environ["nnUNet"], "data")
os.environ['nnUNet_raw_data_base'] = os.path.join(os.environ["nnUNet_data"], "nnUNet_raw_data")
os.environ['nnUNet_preprocessed'] = os.path.join(os.environ["nnUNet_data"], "processed")
os.environ["nnUNet_models"] = os.path.join(os.environ["nnUNet"], "models")
os.environ["RESULTS_FOLDER"] = os.path.join(os.environ["nnUNet"], "output", "preds")
os.environ["nnUNet_preds_post_processed"] = os.path.join(os.environ["nnUNet"], "output", "preds_processed")
os.environ["nnUNet_preds_resampled"] = os.path.join(os.environ["nnUNet"], "output", "preds_resampled")
os.environ["nnUNet_preds_resampled_dcm"] = os.path.join(os.environ["nnUNet"], "output", "preds_resampled_dcm")
os.environ["nnUNet_raw_data"] = os.path.join(os.environ["nnUNet"], "raw_data")
#path where model pre-trained weights are stored
os.environ["PATH_TO_MODEL_FILE"] = os.path.join(os.environ["nnUNet"], "models", "Task024_Prostate.zip")

#misc
os.environ["IDC_Downloads"] = os.path.join(os.getcwd(), "IDC_DL")
os.environ["IDC_Downloads_Sorted"] = os.path.join(os.getcwd(), "IDC_DL", "Sorted")
os.environ["logs"] = os.path.join(os.getcwd(), "logs")

#create dirs for specific folders names
for key, path in os.environ.items():
  check_patterns = [True for el in ["prostatex", "nnunet", "IDC", "nnUNet", "logs", "RESULTS_FOLDER"] if el in key]
  if True in check_patterns:
    # !mkdir -p $path

# %% [markdown]
# # Custom functions

# %%
def convert_image_dcm_to_nrrd(input_path, output_path_root, target_format="nii", prefix=""):
  if not os.path.exists(output_path_root): 
    # !mkdir -p $output_path_root
  # !dcm2niix -z y -m y -f %i_{prefix} -o $output_path_root $input_path
  # out_path_file = f"{output_path_root}/{prefix}.nrrd" 
  # !plastimatch convert \
  # --input $input_path \
  # --output-img $out_path_file

# %%
def convert_seg_to_nii(input_path, output_path):
  if not os.path.exists(output_path): 
    # !mkdir -p $output_path
  
  print(f'input path : {input_path}')
  print(f'output_path : {output_path}')
  # !segimage2itkimage --inputDICOM $input_path --outputDirectory $output_path \
  --outputType nii

# %%
def convert_dcm_sorted(input_path,output_path, idc_df):
  path_dicom = os.environ["prostatex_dicom"] 
  for serie_folder in sorted(glob.glob(os.path.join(input_path, "**", "**", "*"))):#, recursive = True):
    path_serie_dcm_lst = glob.glob(os.path.join(serie_folder, "*.dcm"))
    modality = idc_df[idc_df["SeriesInstanceUID"] == path_serie_dcm_lst[0].split('/')[-2]]["Modality"].iloc[0]#'SEG' if pydicom.dcmread(path_serie_dcm_lst[0]).Modality == "SEG" else "MR"
    seriesInstanceUID = serie_folder.split("/")[-1]
    studyInstanceUID = serie_folder.split("/")[-2]
    patientID = serie_folder.split("/")[-3]
    print(f"Serie processed : {serie_folder}")
    print(f"SeriesDescription : {pydicom.read_file(glob.glob(os.path.join(serie_folder, '*.dcm'))[0]).SeriesDescription}")
    print(f"Modality : {pydicom.read_file(glob.glob(os.path.join(serie_folder, '*.dcm'))[0]).Modality}")
    #convert to nii
    convert_image_dcm_to_nrrd(input_path=serie_folder, 
                           output_path_root=os.path.join(output_path, "nii"),
                           prefix=f"{seriesInstanceUID}")

# %%
# https://pydicom.github.io/pydicom/stable/tutorials/dicom_json.html
def get_seg_dcm_tags_pydicom(seg_path_dcm):
  ds = pydicom.dcmread(seg_path_dcm)
  # print(ds)
  dcm_dict = ds.to_json_dict()
  out_dict = {
  'ReferencedSeriesInstanceUID' : dcm_dict['00081115']['Value'][0]['0020000E']['Value'][0], #RefSerieUID == correspond to T2,
  'StudyInstanceUID' : dcm_dict['0020000D']['Value'][0],
  'patientID' : dcm_dict['00100020']['Value'][0],# patientID 
  'SOPClassUID' : dcm_dict['00080016']['Value'][0], # SOP Class UID
  'SOPInstanceUID' : dcm_dict['00080018']['Value'][0],
  'SeriesInstanceUID' : dcm_dict['0020000E']['Value'][0],
  'Modality' : dcm_dict['00080060']['Value'][0], # Modality 
  'SeriesDescription' : dcm_dict['0008103E']['Value'][0], # SeriesDescription
  'studydesc' : dcm_dict['00081030']['Value'][0], # StudyDescription
  'series_time' : dcm_dict['00080031']['Value'][0],#SeriesTime
  'study_time' : dcm_dict['00080030']['Value'][0],#StudyTime
  'series_date' : dcm_dict['00080021']['Value'][0], #SeriesDate
  'study_date' : dcm_dict['00080020']['Value'][0] #StudyDate
  }
  # 00081115 == Referenced Series Sequence
  # 0020000E == Referenced Series Instance UID
  return out_dict

# %%
def add_ohif_url_nnunet(row, datastore='', dataset='', app=''):
    #test
    app='fir-idc-prostate-ohif.web.app'
    project='idc-sandbox-003'
    location='us-central1'
    dataset='prostate-seg'
    datastore='whole_prostate_nnunet_id24_2ServersIDC' #whole_prostate_nnunet_id24_2ServersIDC #pz_tz_nnunet_id05_2ServersIDC
    studyUID = row['StudyInstanceUID']
    return f'https://{app}/viewer/{studyUID}!secondGoogleServer=/projects/{project}/locations/{location}/datasets/{dataset}/dicomStores/{datastore}'
    #"https://fir-idc-prostate-ohif.web.app/projects/idc-sandbox-003/locations/us-central1/datasets/prostate-seg/dicomStores/prostatex_no_gt_datastore/study/"+studyUID

# %%
def download_idc_data_serie_uid(idc_df):
  # save the list of GCS URLs into a file
  selection_manifest = os.path.join(os.environ["IDC_Downloads"], "idc_manifest.txt")
  idc_df["gcs_url"].to_csv(selection_manifest, header=False, index=False)
  # let's make sure the download folder is clean, in case you ran this cell earlier
  # for a different dataset
  # !rm -rf {os.environ["IDC_Downloads"]+"/*.dcm"}
  # !cat {selection_manifest} | gsutil -m cp -I {os.environ["IDC_Downloads"]}
  # !python dicomsort/dicomsort.py -k -u {os.environ["IDC_Downloads"]} {os.environ["IDC_Downloads_Sorted"]}/%PatientID/%StudyInstanceUID/%SeriesInstanceUID/%SOPInstanceUID.dcm
  # !rm -rf {os.environ["qin_prostate_rep_dicom"]+"/*"} 
  # !mv {os.environ['IDC_Downloads_Sorted']+'/*'} {os.environ["prostatex_dicom"]}
  convert_dcm_sorted(input_path=os.environ["prostatex_dicom"],
                  output_path=os.environ["prostatex_root"], idc_df=selection_df)
  return selection_df

# %%
def reformat_image_nnunet():
  #reformats images to correct format, 
  #from global path to nnunet folder==nnUNet preprocessed
  for mr_vol in glob.glob(os.path.join(os.environ["prostatex_nii"], f"*.nii.gz")):
    serieUID = mr_vol.split('/')[-1].split("_")[1].replace(".nii.gz","")#.split(".")[0]
    patientID = mr_vol.split('/')[-1].split("_")[0]
    nnunet_idx = "0000" #if "T2" in mr_vol.split('/')[-2] else "0001"#0000 for T2 and 0001 for ADC
    nnunet_path = os.path.join(os.environ["nnUNet_preprocessed"], 
                                "_".join([patientID, serieUID, nnunet_idx]) + ".nii.gz") 
    # !cp $mr_vol $nnunet_path

# %%
def largest_component_retrieval(input_path : str, output_path=None):
    """Largest component retrieval 
    Args:
        input_path (str): input seg nifti path, binary image
        output_path (str): output_path after conversion
    Convert binary image into a connected component image, each component has an integer label.
    Relabel components so that they are sorted according to size (there is an optional minimumObjectSize parameter to get rid of small components).
    Get largest connected componet, label==1 in sorted component image.
    """
    assert os.path.exists(input_path)
    input_image = sitk.ReadImage(input_path, imageIO="NiftiImageIO")
    assert len(np.unique(sitk.GetArrayFromImage(input_image))) == 2 # make sure its a binary image
    component_image = sitk.ConnectedComponent(input_image)
    sorted_component_image = sitk.RelabelComponent(component_image, sortByObjectSize=True)
    largest_component_binary_image = sorted_component_image == 1
    if output_path is not None: 
        # assert os.path.exists(output_path)
        print(output_path)
        sitk.WriteImage(largest_component_binary_image, output_path, imageIO="NiftiImageIO")
    else:
        print("No writing on disk of largest component of input.")
    # sanity checks == logs
    print(f"Input path : {input_path}")
    print(f"Output path : {output_path}")
    print(f"Number of components found : {len(np.unique(sitk.GetArrayFromImage(sorted_component_image)))}")
    # print("Done!")
    # print("\n")

# %%
def resample_preds(input_path_nnunet_preds="", input_path_t2_idc="", output_path=""):
  for pred_path in sorted(glob.glob(os.path.join(input_path_nnunet_preds, "*.nii.gz"))):
    search_t2_path = os.path.join(input_path_t2_idc, \
                                  f"{pred_path.split('/')[-1].split('_')[0]}_{pred_path.split('/')[-1].split('_')[1].replace('.nii.gz','')}*.nii.gz") #PatientID_SerieUID.nii.gz
                                      #get serieUID
    print(f"search path for {desired_grid} : {search_t2_path}")
    t2_path = glob.glob(search_t2_path, recursive=True)[0]                              
    print(f"{desired_grid}_path found : {t2_path}")
    print(f"pred path : {pred_path}")
    out_processed = os.path.join(os.environ["nnUNet_preds_post_processed"], pred_path.split("/")[-1])
    largest_component_retrieval(input_path=pred_path,output_path=out_processed)
    resample_args_to_t2_origin = {"input" : out_processed,#change to pred path if no largest_component_retrieval necessary 
                          "output" : os.path.join(output_path, 
                                                  f"{pred_path.split('/')[-1][:-7]}_resampled.nii.gz"),
                          "fixed" : t2_path,
                          "interpolation" : "nn"}
    
    path_log = os.path.join(os.environ["logs"], 'log_pypla_res_pred' + pred_path.split('/')[-1].split('.')[0] + '.txt')            
    # !touch $path_log
    pypla.resample(verbose = False, **resample_args_to_t2_origin, path_to_log_file=path_log)
    print()

# %%
def seg_nii_to_dicom(idc_df, input_path_nii="", input_path_dcm_idc="", output_path_root=""):
  assert os.path.exists(input_path_nii)
  assert os.path.exists(input_path_dcm_idc)
  # !mkdir -p $output_path_root
  for nii_seg_pred in glob.glob(os.path.join(input_path_nii, '*.nii.gz')):
    patID = nii_seg_pred.split('/')[-1].split('_')[0]
    study_mr_t2_serieUID = nii_seg_pred.split('/')[-1].split('_')[1].replace(".nii.gz","")

    # study_mr_t2_serieUID = idc_df[idc_df["StudyInstanceUID"] == study_current]["SeriesInstanceUID"].unique()[0]
    #find t2 dcm folder
    t2_dcm_folder = glob.glob(os.path.join(input_path_dcm_idc, patID, "**", study_mr_t2_serieUID))[0]
    #find seg dcm file
    # find nii seg folder == preds resampled
    assert os.path.exists(t2_dcm_folder)
    print('\nConverting...')
    print(f'pred nnunet processed : {nii_seg_pred}')
    print(f't2_dcm_folder : {t2_dcm_folder}')
    output_path = os.path.join(output_path_root, '_'.join([patID, study_mr_t2_serieUID])+'.dcm')
    #find gt seg dcm file == orginal idc dcm files
    #convert nii pred to dcm
    # !itkimage2segimage --inputImageList $nii_seg_pred \
    --inputDICOMDirectory  $t2_dcm_folder \
    --inputMetadata  $seg_dcm_metadata_json_file \
    --outputDICOM $output_path 
    print("Done!")

# %% [markdown]
# # Auth login

# %%
import os
# dcm2niix 
# !sudo apt-get install dcm2niix 
# cmd = 'dcm2niix -z y -m y -o %s  %s ' % (pat_dir_nifti_path, path_to_dicom_ct_folder)
# print(cmd)
# ret = os.system(cmd)
# print (ret)
# !pip install dcm2niix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# dcm2niix is already the newest version (1.0.20181125-1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %% [markdown]
# ##Colab

# %%
#colab 
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# # Setup GCP Project ID

# %%
project_id = "idc-sandbox-003"
os.environ["GCP_PROJECT_ID"] = project_id

# %%
print(os.environ["nnUNet_models"])
# Out:
# /content/nnUNet/models

# %% [markdown]
# # Setup of the Colab VM
#
#
#
# In the following cells we will confirm you have a GPU before doing anything else, and will install and import all the Python dependencies.
#
# The main python packages we need to install are:
# * `nnunet` - which is the [codebase for the nn-UNet framework](https://github.com/MIC-DKFZ/nnUNet) we are going to be using for the segmentation step;
# * `pydicom`, a Python [package](https://github.com/pydicom/pydicom) that lets the use read, modify, and write DICOM data in an easy "pythonic" way - that we are going to use to distinguish different DICOM objects from each other.

# %% [markdown]
# ## GPU checks

# %%
# check wether the Colab Instance was correctly initialized with a GPU instance
gpu_list = !nvidia-smi --list-gpus

has_gpu = False if "failed" in gpu_list[0] else True

if not has_gpu:
  print("Your Colab VM does not have a GPU - check \"Runtime > Change runtime type\"")

# %%
# check which model of GPU the notebook is equipped with - a Tesla K80 or T4
# T4 is the best performing on the two - and can about half the GPU processing time

# !nvidia-smi
# Out:
# Mon May 15 06:40:19 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Environment Setup
#
# Here we will configure the Linux environment variables needed to run the nnU-Net pipeline.
#
# Three main variables are needed by default to run the nnU-Net segmentation pipelines:
# * `nnUNet_raw_data_base` is the path to the folder where the segmentation pipeline expects to find the data to process;
# * `nnUNet_preprocessed` is the path to the folder where the preprocessed data are saved;
# * `RESULTS_FOLDER` is the path to the folder storing by default the model weights and, in our case, for simplicity, the segmentation masks produced by the pipeline.
#
# We will use the additional variable `PATH_TO_MODEL_FILE` to point to the location where the pre-trained model weights for the chosen model will be stored (more on this later).
#
# Please notice that these variables need to be set using `os.environ[]` in Google Colab - as `!export` is not sufficient to guarantee the variables are kept from one cell to the other. For more in-depth information regarding what the nnU-Net framework uses these folders for, please visit [the dedicated nnU-Net documentation page](https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/setting_up_paths.md)

# %% [markdown]
# ## Install command-line tools
#
#
# [Plastimatch](https://plastimatch.org/index.html) is considered to be the swiss army knife of medical images processing: we will use it to convert DICOM (CT, RTSTRUCT) series to NRRD files - but it can be used for a multitude of other tasks, such as registration, resampling, cropping, and computing statistics to name a few. Plastimatch is also available as a 3DSlicer plug-in and can be used directly from the Slicer GUI.
#
# For the sake of clarity and simplicity, we will call Plastimatch from a very simple [Python wrapper](https://github.com/denbonte/pyplastimatch) written for the occasion (unfortunately, Plastimatch does not provide an official one).

# %%
# %%capture
# !sudo apt update

# !sudo apt install plastimatch

# %%
# !echo $(plastimatch --version)
# Out:
# plastimatch version 1.8.0

# %% [markdown]
# [dcmqi](https://github.com/QIICR/dcmqi) is an open source library that can help with the conversion between imaging research formats and the standard DICOM representation for image analysis results. More specifically, you can use dcmqi convert DICOM Segmentation objects (DICOM SEG) into research formats, such as NIfTI and NRRD.

# %%
# %%capture
# !wget https://github.com/QIICR/dcmqi/releases/download/v1.2.5/dcmqi-1.2.5-linux.tar.gz
# !tar zxvf dcmqi-1.2.5-linux.tar.gz
# !cp dcmqi-1.2.5-linux/bin/* /usr/local/bin/

# %% [markdown]
# Finally, we are going to install [Subversion](https://subversion.apache.org/), a tool that will allow us to clone GitHub repositories only partially (to save time and space).

# %%
# %%capture

# !sudo apt install subversion

# %%
# !echo $(svn --version | head -n 2)
# Out:
# svn, version 1.13.0 (r1867053) compiled May 12 2022, 20:47:08 on x86_64-pc-linux-gnu

# %% [markdown]
# ## Install Python packages

# %%
# %%capture
# !pip install nnunet
# !pip install pydicom
# !pip install nibabel
# !pip install dcm2niix
# !pip install SimpleITK

# %% [markdown]
# Unpack and install model we downloaded earlier (under `PATH_TO_MODEL_FILE`). This step can take about 1-2 minutes.

# %%
# %%capture
# !nnUNet_install_pretrained_model_from_zip $PATH_TO_MODEL_FILE

# %% [markdown]
# Next we set up few things to help with visualization of the segmentations later.

# %%
import os
import sys
import shutil
import csv
import random

import os
import glob
import csv
import json

import nibabel as nib

import time
import gdown

import json
import pprint
import numpy as np
import pandas as pd

import pydicom
import nibabel as nib
import SimpleITK as sitk

# from medpy.metric.binary import dc as dice_coef
# from medpy.metric.binary import hd as hausdorff_distance
# from medpy.metric.binary import asd as avg_surf_distance

# from medpy.filter.binary import largest_connected_component

# use the "tensorflow_version" magic to make sure TF 1.x is imported
# %tensorflow_version 2.x
# import tensorflow as tf
# import keras

print("\nThis Colab instance is equipped with a GPU.")
# Out:
# This Colab instance is equipped with a GPU.

# %%
# PyPlastimatch - python wrapper for Plastimatch (and interactive notebook visualisation)
# !svn checkout https://github.com/AIM-Harvard/pyplastimatch/trunk/pyplastimatch pyplastimatch
# Out:
# A    pyplastimatch/__init__.py
# A    pyplastimatch/pyplastimatch.py
# A    pyplastimatch/utils
# A    pyplastimatch/utils/__init__.py
# A    pyplastimatch/utils/data.py
# A    pyplastimatch/utils/eval.py
# A    pyplastimatch/utils/viz.py
# Checked out revision 25.

# %%
# dicomsort is the pythong package that can sort DICOM files into
# folder organization based on user-specified DICOM attributes
# !git clone https://github.com/pieper/dicomsort.git
# Out:
# Cloning into 'dicomsort'...
# remote: Enumerating objects: 169, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 169 (delta 23), reused 34 (delta 17), pack-reused 126
# Receiving objects: 100% (169/169), 87.85 KiB | 1010.00 KiB/s, done.
# Resolving deltas: 100% (86/86), done.

# %%
from pyplastimatch import pyplastimatch as pypla
from pyplastimatch.utils import viz as viz_utils
from pyplastimatch.utils import data as data_utils

# %% [markdown]
# # Data selection, downloading and structuring -- Conversion to DICOM
#
# We want to select here the collection named qin-prostate repeatibility, and more particularly the two timepoints per patient ID for further analysis.

# %% [markdown]
# In order to use data hosted by IDC effectively, you will need to utilize metadata to navigate what data is available and to select specific files that are relevant in your analysis. The main metadata table you will need for this purpose is the [`bigquery-public-data.idc_current.dicom_all`](https://console.cloud.google.com/bigquery?p=bigquery-public-data&d=idc_current&t=dicom_all&page=table) table.
#
# This query has one row per file hosted by IDC. All of IDC data is in DICOM format, and each of the rows in this table will have all of the DICOM attributes extracted from a given file. It will also have various columns containing non-DICOM metadata, such as the name of the collection where the file is included, size of the file, and URL that can be used to retrieve that file.
#
# To query IDC BigQuery tables, you can use one of the following approaches:
# 1. `%%bigquery` magic will allow you to define your query in plain SQL, and load the result of the query into a Pandas dataframe.
# 2. [BigQuery Python API](https://googleapis.dev/python/bigquery/latest/index.html) is more flexible in allowing you to parameterize your query.
# 3. [Google Cloud BigQuery console](https://console.cloud.google.com/bigquery) is very convenient for interactive query exploration of tables.
# 4. [`gcloud bq`](https://cloud.google.com/bigquery/docs/bq-command-line-tool) is the command line tool that comes as part of [Cloud SDK](https://cloud.google.com/sdk) and is convenient for scripting interactions from the shell. Cloud SDK is preinstalled on Colab.
#
# In the following cells we will utilize `%%bigquery`, Python BigQuery SDK and BigQuery console for working with IDC BigQuery tables.
#
# First, to verify that you are authenticated, and your project ID is working, let's run a test query against IDC BigQuery table to get the summary statistics about the  of data available in IDC.

# %% [markdown]
# Given `SeriesInstanceUID` value identifying the image series, we can query the IDC metadata table to get the list of files (defined by the Google Storage URLs) corresponding to this series.
#
# All of the DICOM metadata for each of the DICOM files is available in the BigQuery table we will be querying. We will get not just the `gcs_url`, but also identifiers for the Study, Series and Instance, to better understand organization of data, and since `StudyInstanceUID` will be handy later when we get to the visualization of the data.

# %%
from google.cloud import bigquery
bq_client = bigquery.Client(os.environ["GCP_PROJECT_ID"])

# %%
selection_query = f"""
  SELECT
    dc_all.*
  FROM
    `bigquery-public-data.idc_v14.dicom_all` AS dc_all
  WHERE
    dc_all.collection_id = 'qin_prostate_repeatability'
    AND dc_all.Modality = 'MR'
    AND dc_all.SeriesDescription = 'T2 Weighted Axial'
  ORDER BY
    PatientID"""
selection_result = bq_client.query(selection_query)
selection_df = selection_result.result().to_dataframe()
selection_result = bq_client.query(selection_query)
selection_df = selection_result.result().to_dataframe()

# %% [markdown]
# Get SerieUIDs in bucket processed from nnunet

# %%
# !rm bucketUIDs_processed.csv
# !gcloud storage ls --recursive gs://idc_qin_prostate_repeatability/model1/preds_processed_dcm/* > bucketUIDs_processed.csv
sereUID_processed_dcm = pd.read_csv("bucketUIDs_processed.csv", names=["serieUID"], skiprows=[0])
seriesInstanceUID_dcm_processed_lst = [x.split("/")[-1].split("_")[1].replace(".dcm", "") for x in sereUID_processed_dcm.serieUID.values]
# Out:
# rm: cannot remove 'bucketUIDs_processed.csv': No such file or directory

# %%
serieUID_current_lst = list(set(selection_df.SeriesInstanceUID.values) - set(seriesInstanceUID_dcm_processed_lst))

# %%
len(serieUID_current_lst)
# Out:
# 30

# %% [markdown]
# # Main loop

# %%
seg_whole_prostate_json = "https://www.dropbox.com/s/yhkqnbqqc9fhgps/task024_whole_prostate.json?dl=0"
seg_dcm_metadata_json_file = "pred_metadata.json"#"/content/nnUnet/models/Task024_Promise.zip"
# !wget -O $seg_dcm_metadata_json_file $seg_whole_prostate_json
# Out:
# --2023-05-15 06:46:54--  https://www.dropbox.com/s/yhkqnbqqc9fhgps/task024_whole_prostate.json?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/yhkqnbqqc9fhgps/task024_whole_prostate.json [following]
# --2023-05-15 06:46:55--  https://www.dropbox.com/s/raw/yhkqnbqqc9fhgps/task024_whole_prostate.json
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc724ed79cd4501fc1544091f117.dl.dropboxusercontent.com/cd/0/inline/B8HjPyJUMuZkCR3RFWrQ9-Sv5PquE-el1UGwHGTUvjXJaqLAptUbZSP1A4IS6eNl8sSgju201V9L5NYxvs6cPbaaJ6Y2bxHEphde7uUz0J7zTiA4sn5aAzt3XpXR3UkG_RR5cMumRhvkWUZRJ4KgnkmHpICC3Fn7uJAMxeJvzkk74w/file# [following]
# --2023-05-15 06:46:55--  https://uc724ed79cd4501fc1544091f117.dl.dropboxusercontent.com/cd/0/inline/B8HjPyJUMuZkCR3RFWrQ9-Sv5PquE-el1UGwHGTUvjXJaqLAptUbZSP1A4IS6eNl8sSgju201V9L5NYxvs6cPbaaJ6Y2bxHEphde7uUz0J7zTiA4sn5aAzt3XpXR3UkG_RR5cMumRhvkWUZRJ4KgnkmHpICC3Fn7uJAMxeJvzkk74w/file
# Resolving uc724ed79cd4501fc1544091f117.dl.dropboxusercontent.com (uc724ed79cd4501fc1544091f117.dl.dropboxusercontent.com)... 162.125.80.15, 2620:100:6035:15::a27d:550f
# Connecting to uc724ed79cd4501fc1544091f117.dl.dropboxusercontent.com (uc724ed79cd4501fc1544091f117.dl.dropboxusercontent.com)|162.125.80.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 983 [text/plain]
# Saving to: ‘pred_metadata.json’
#
# pred_metadata.json  100%[===================>]     983  --.-KB/s    in 0s
#
# 2023-05-15 06:46:56 (274 MB/s) - ‘pred_metadata.json’ saved [983/983]

# %% [markdown]
# ## Download and install nnUnet pre-trained model -- task024 -- personal dropbox
#
# nnUnet pre-trained models zip files can also be found [here](https://zenodo.org/record/4003545#.YsWmH-zMLt8).

# %%
# %%capture
# this will usually take between one and five minutes (but can sometimes take up to eight)
seg_model_url = "https://www.dropbox.com/s/u9m37l8et4hgu4h/Task024_Promise.zip?dl=0"
out_path_mod = os.path.join(os.environ["nnUNet_models"], "Task024_Promise.zip")#"/content/nnUnet/models/Task024_Promise.zip"
# !wget -O $out_path_mod $seg_model_url
# !nnUNet_install_pretrained_model_from_zip $out_path_mod

# %%
def reset_folders():
  for key, path in os.environ.items():
    check_patterns = [True for el in ["nnUNet_preprocessed", "nnUNet_preds_post_processed", \
                                      "prostatex", "IDC_Downloads", "IDC_Downloads_Sorted", \
                                      "prostatex_dicom", "prostatex_root", "nnUNet_preds_resampled"] if el in key]
    if True in check_patterns:
      # !rm -rf $path
      # !mkdir -p $path
  # !rm /content/nnUNet/output/preds/*.nii.gz

# %%
#whole process
for serieUID_current in serieUID_current_lst:
  #reset processing folders
  reset_folders()
  #download idc data
  idc_df = download_idc_data_serie_uid(idc_df=selection_df[selection_df.SeriesInstanceUID \
                                                           == serieUID_current])
  ##reformat idc input data
  reformat_image_nnunet()
  # Inference on IDC data
  # !nnUNet_predict --input_folder {os.environ["nnUNet_preprocessed"]} \
                --output_folder {os.environ["RESULTS_FOLDER"]} \
                --task_name "Task024_Promise" --model $model_type \
                --save_npz 
  # resample
  resample_preds(input_path_nnunet_preds=os.environ["RESULTS_FOLDER"],\
                  input_path_t2_idc=os.environ["prostatex_nii"], output_path=os.environ["nnUNet_preds_resampled"])
  # Convert nnunet preds to dicom
  seg_nii_to_dicom(idc_df=idc_df, input_path_nii=os.environ["nnUNet_preds_resampled"], \
                   input_path_dcm_idc=os.environ["prostatex_dicom"], output_path_root=os.environ["nnUNet_preds_resampled_dcm"])
  # #upload to buckets
  # !gsutil -m cp -r {os.environ['nnUNet_preds_resampled_dcm']}/* gs://idc_qin_prostate_repeatability/model1/preds_processed_dcm/
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 8, 17], [0], [0]]
# number of tiles: 3
# using precomputed Gaussian
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 45, 256, 256)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 8, 17], [0], [0]]
# number of tiles: 3
# using precomputed Gaussian
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 45, 256, 256)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 8, 17], [0], [0]]
# number of tiles: 3
# using precomputed Gaussian
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 45, 256, 256)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 8, 17], [0], [0]]
# number of tiles: 3
# using precomputed Gaussian
# prediction done
# inference done. Now waiting for the segmentation export to finish...
# force_separate_z: None interpolation order: 1
# separate z: True lowres axis [0]
# separate z, order in z is 0 order inplane is 1
# postprocessing...
# search path for T2 : /content/prostateX/nii/PCAMPMRI-00015_1.3.6.1.4.1.14519.5.2.1.3671.4754.212056086412825832650405216150*.nii.gz
# T2_path found : /content/prostateX/nii/PCAMPMRI-00015_1.3.6.1.4.1.14519.5.2.1.3671.4754.212056086412825832650405216150.nii.gz
# pred path : /content/nnUNet/output/preds/PCAMPMRI-00015_1.3.6.1.4.1.14519.5.2.1.3671.4754.212056086412825832650405216150.nii.gz
# /content/nnUNet/output/preds_processed/PCAMPMRI-00015_1.3.6.1.4.1.14519.5.2.1.3671.4754.212056086412825832650405216150.nii.gz
# Input path : /content/nnUNet/output/preds/PCAMPMRI-00015_1.3.6.1.4.1.14519.5.2.1.3671.4754.212056086412825832650405216150.nii.gz
# Output path : /content/nnUNet/output/preds_processed/PCAMPMRI-00015_1.3.6.1.4.1.14519.5.2.1.3671.4754.212056086412825832650405216150.nii.gz
# Number of components found : 2
#
#
# Converting...
# pred nnunet processed : /content/nnUNet/output/preds_resampled/PCAMPMRI-00015_1.3.6.1.4.1.14519.5.2.1.3671.4754.212056086412825832650405216150_resampled.nii.gz
# t2_dcm_folder : /content/prostateX/dicom/PCAMPMRI-00015/1.3.6.1.4.1.14519.5.2.1.3671.4754.182983245842036631781777324507/1.3.6.1.4.1.14519.5.2.1.3671.4754.212056086412825832650405216150
# dcmqi repository URL: git@github.com:QIICR/dcmqi.git revision: 1153738 tag: v1.2.5
# Loaded segmentation from /content/nnUNet/output/preds_resampled/PCAMPMRI-00015_1.3.6.1.4.1.14519.5.2.1.3671.4754.212056086412825832650405216150_resampled.nii.gz
# Searching recursively /content/prostateX/dicom/PCAMPMRI-00015/1.3.6.1.4.1.14519.5.2.1.3671.4754.182983245842036631781777324507/1.3.6.1.4.1.14519.5.2.1.3671.4754.212056086412825832650405216150 for DICOM files
# W: CodeValue (0008,0100) empty in CodeSequenceMacro (type 1C)
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.291781963246457177240101774008 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.223378388472835409926589462539 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.197758900485730584483857674557 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.185392616443358457360626384922 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.264283689375706549544990212242 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.225595800187231348709147561916 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.150412840152030624976649288729 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.261978505499197982367267562015 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.572887822592345962686801525460 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.191839481931152907230997922631 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.142385071334231029542702592572 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.181719362494785370041992761670 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.174774150789314599385514377402 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.180249413208195869195502276906 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.244559086269408555568201641947 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.516402116644927068524230030623 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.495047548766853787201846981058 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.236927589984106290730253404160 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.271353471538418331678610423056 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.283809938493229219652535001306 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.589637209944971865833790889232 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.207360571014562512846696728386 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.268320283778527620152555346670 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.173335211426363620684201258694 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.255164891854158487143992989185 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.142153806317242476305998435716 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.801204651049382587033651886436 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.330818958105132150268816333900 mapped
# 28 of 28 slices mapped to source DICOM images
# Found 2 label(s)
# Processing label 1
# Total non-empty slices that will be encoded in SEG for label 1 is 28
#  (inclusive from 0 to 28)
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Saved segmentation as /content/nnUNet/output/preds_resampled_dcm/PCAMPMRI-00015_1.3.6.1.4.1.14519.5.2.1.3671.4754.212056086412825832650405216150.dcm
# Done!
# Copying file:///content/nnUNet/output/preds_resampled_dcm/PCAMPMRI-00015_1.3.6.1.4.1.14519.5.2.1.3671.4754.212056086412825832650405216150.dcm [Content-Type=application/dicom]...
# \
# Operation completed over 1 objects/917.2 KiB.
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/fe103438-cc61-4211-993e-5e0190679b4c.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/14697933-beb4-4741-bc58-69c5c8188e7b.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/e0fdad83-6cbc-4508-9661-48c8e569e034.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/2f68ea85-3e08-4394-93a0-a0a1369aa25e.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/d33bd56e-f719-4adc-ac10-f8dfefe50ec2.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/3755e3a3-1f7b-45b1-92eb-4c5ce16676e5.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/4a770e3c-9a2a-437e-b52d-e1c079e0b8ee.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/c6e6abc5-a423-43d2-91e5-72e8acdbf29b.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/bde7acea-273e-4180-942d-96c6120b9598.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/1b28411e-fe2d-4470-a868-05d0ff791275.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/7dfe4fdf-61ad-4fac-8d97-2ce38bb45a56.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/37afa1dc-e0b8-452e-bc33-4896248b5224.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/3640e717-0319-4c9a-8dfb-34b7e578dd83.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/fba68370-eb2d-4f7c-be3f-f4e88dd1e3d5.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/93d51a09-c860-4491-9b8f-af71fa0040bc.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/e8c13ed5-bfb3-421a-bb53-05e007b8430f.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/59f70975-0227-4e77-b4d0-debe30caca20.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/d044ac59-b805-4d05-a0e8-03fcf6f35c29.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/f72420ce-87fc-44dd-b3a9-32b4ec66d160.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/177038eb-c64c-4a29-93d2-c84ae426e3fb.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/e96b18b2-fbef-486d-9df8-0013ee37177d.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/b64cf7cc-96d6-4ba5-acba-9785f2c18b09.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/92b2ebfd-a07b-4ff0-90ff-cac7fc78f815.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/f7ee5179-d8d0-4c9b-aa08-7a5c08431a21.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/a662b5a8-baec-4275-8aca-4dd70bb0f871.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/ac32894b-adc3-462f-a20b-bb3ae2bccb21.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/0160ea73-a427-43dd-8e17-3dfa7fe91844.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/386cd5a1-8e23-4668-b68e-a5f366dd74ca.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/a073e0db-ade9-44ad-9ee8-73a73a57bbfa.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/b3e421ab-e8c6-483b-9b3d-892444362d23.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/8babf05a-b238-4be4-90c2-39ab86e680fe.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/3840c2a9-317d-4238-9c81-5f5ced13e87b.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/314e823c-01e8-48e3-b27f-21f8fe798c94.dcm...
# Copying gs://public-datasets-idc/2409ba66-93dc-4236-8cba-35be541e61f0/8c5cd80d-e336-4990-b38d-c967621aaeb5.dcm...
# | [34/34 files][ 17.1 MiB/ 17.1 MiB] 100% Done   2.2 MiB/s ETA 00:00:00
# Operation completed over 34 objects/17.1 MiB.
# 100% 35/35 [00:00<00:00, 444.67it/s]
# Files sorted
# Serie processed : /content/prostateX/dicom/PCAMPMRI-00006/1.3.6.1.4.1.14519.5.2.1.3671.4754.287814201869490350714498330797/1.3.6.1.4.1.14519.5.2.1.3671.4754.124813816937601110554342446480
# SeriesDescription : T2 Weighted Axial
# Modality : MR
# Chris Rorden's dcm2niiX version v1.0.20220505  GCC9.4.0 x86-64 (64-bit Linux)
# Found 34 DICOM file(s)
# Convert 34 DICOM as /content/prostateX/nii/PCAMPMRI-00006_1.3.6.1.4.1.14519.5.2.1.3671.4754.124813816937601110554342446480 (512x512x34x1)
# Conversion required 1.284530 seconds (1.284328 for core code).
#
#
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# using model stored in  /content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1
# This model expects 1 input modalities for each image
# Found 1 unique case ids, here are some examples: ['PCAMPMRI-00006_1.3.6.1.4.1.14519.5.2.1.3671.4754.124813816937601110554342446480']
# If they don't look right, make sure to double check your filenames. They must end with _0000.nii.gz etc
# number of cases: 1
# number of cases that still need to be predicted: 1
# emptying cuda cache
# loading parameters for folds, None
# folds is None so we will automatically look for output folders (not using 'all'!)
# found the following folds:  ['/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_0', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_1', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_2', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_3', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_4']
# 2023-05-15 07:03:50.610688: Using dummy2d data augmentation
# using the following model files:  ['/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_0/model_final_checkpoint.model', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_1/model_final_checkpoint.model', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_2/model_final_checkpoint.model', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_3/model_final_checkpoint.model', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_4/model_final_checkpoint.model']
# starting preprocessing generator
# starting prediction...
# preprocessing /content/nnUNet/output/preds/PCAMPMRI-00006_1.3.6.1.4.1.14519.5.2.1.3671.4754.124813816937601110554342446480.nii.gz
# using preprocessor GenericPreprocessor
# before crop: (1, 34, 512, 512) after crop: (1, 34, 504, 512) spacing: [3.     0.3125 0.3125]
#
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([3.    , 0.3125, 0.3125]), 'spacing_transposed': array([3.    , 0.3125, 0.3125]), 'data.shape (data is transposed)': (1, 34, 504, 512)}
# after:  {'spacing': array([2.20004711, 0.61250001, 0.61250001]), 'data.shape (data is resampled)': (1, 46, 257, 261)}
#
# (1, 46, 257, 261)
# This worker has ended successfully, no errors to report
# predicting /content/nnUNet/output/preds/PCAMPMRI-00006_1.3.6.1.4.1.14519.5.2.1.3671.4754.124813816937601110554342446480.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 46, 257, 261)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 9, 18], [0, 1], [0, 5]]
# number of tiles: 12
# computing Gaussian
# done
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 46, 257, 261)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 9, 18], [0, 1], [0, 5]]
# number of tiles: 12
# using precomputed Gaussian
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 46, 257, 261)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 9, 18], [0, 1], [0, 5]]
# number of tiles: 12
# using precomputed Gaussian
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 46, 257, 261)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 9, 18], [0, 1], [0, 5]]
# number of tiles: 12
# using precomputed Gaussian
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 46, 257, 261)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 9, 18], [0, 1], [0, 5]]
# number of tiles: 12
# using precomputed Gaussian
# prediction done
# inference done. Now waiting for the segmentation export to finish...
# force_separate_z: None interpolation order: 1
# separate z: True lowres axis [0]
# separate z, order in z is 0 order inplane is 1
# postprocessing...
# search path for T2 : /content/prostateX/nii/PCAMPMRI-00006_1.3.6.1.4.1.14519.5.2.1.3671.4754.124813816937601110554342446480*.nii.gz
# T2_path found : /content/prostateX/nii/PCAMPMRI-00006_1.3.6.1.4.1.14519.5.2.1.3671.4754.124813816937601110554342446480.nii.gz
# pred path : /content/nnUNet/output/preds/PCAMPMRI-00006_1.3.6.1.4.1.14519.5.2.1.3671.4754.124813816937601110554342446480.nii.gz
# /content/nnUNet/output/preds_processed/PCAMPMRI-00006_1.3.6.1.4.1.14519.5.2.1.3671.4754.124813816937601110554342446480.nii.gz
# Input path : /content/nnUNet/output/preds/PCAMPMRI-00006_1.3.6.1.4.1.14519.5.2.1.3671.4754.124813816937601110554342446480.nii.gz
# Output path : /content/nnUNet/output/preds_processed/PCAMPMRI-00006_1.3.6.1.4.1.14519.5.2.1.3671.4754.124813816937601110554342446480.nii.gz
# Number of components found : 2
#
#
# Converting...
# pred nnunet processed : /content/nnUNet/output/preds_resampled/PCAMPMRI-00006_1.3.6.1.4.1.14519.5.2.1.3671.4754.124813816937601110554342446480_resampled.nii.gz
# t2_dcm_folder : /content/prostateX/dicom/PCAMPMRI-00006/1.3.6.1.4.1.14519.5.2.1.3671.4754.287814201869490350714498330797/1.3.6.1.4.1.14519.5.2.1.3671.4754.124813816937601110554342446480
# dcmqi repository URL: git@github.com:QIICR/dcmqi.git revision: 1153738 tag: v1.2.5
# Loaded segmentation from /content/nnUNet/output/preds_resampled/PCAMPMRI-00006_1.3.6.1.4.1.14519.5.2.1.3671.4754.124813816937601110554342446480_resampled.nii.gz
# Searching recursively /content/prostateX/dicom/PCAMPMRI-00006/1.3.6.1.4.1.14519.5.2.1.3671.4754.287814201869490350714498330797/1.3.6.1.4.1.14519.5.2.1.3671.4754.124813816937601110554342446480 for DICOM files
# W: CodeValue (0008,0100) empty in CodeSequenceMacro (type 1C)
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.210587772025738245457979760039 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.326498669775758650937526315757 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.447413652400468909410385262955 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.168964503688952983895501194788 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.298228647870388030544825675692 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.945446335115061371123736813002 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.148157642378408154095210675634 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.167295443524527387120834626739 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.922064462901219899307118042898 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.220309436491053692298569862177 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.532302821930243618564565413703 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.303031770435993493402216269973 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.301782389809554799910630350659 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.226145895906412371801497931524 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.257696254222819510997469601926 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.186914671392695197456302899501 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.314897629572007066816343046558 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.333720110620500675889782006452 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.206201869056721848930358144099 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.570712353813300880117337234736 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.113374588623320697860707459380 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.281556140757699415215541859543 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.735682385664604203782535412457 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.137007209906909377513518745555 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.178719232473343855868511409763 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.106651732420289279321552988263 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.277286790468448978492162723876 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.189690029370632045711016084532 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.224882171352685380429852704506 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.273240553232246514042619174515 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.129340196072187422776274203960 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.160262306103372072346972681704 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.218546959779757988759577342378 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.547054099949479671341024928308 mapped
# 34 of 34 slices mapped to source DICOM images
# Found 2 label(s)
# Processing label 1
# Total non-empty slices that will be encoded in SEG for label 1 is 34
#  (inclusive from 0 to 34)
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Saved segmentation as /content/nnUNet/output/preds_resampled_dcm/PCAMPMRI-00006_1.3.6.1.4.1.14519.5.2.1.3671.4754.124813816937601110554342446480.dcm
# Done!
# Copying file:///content/nnUNet/output/preds_resampled_dcm/PCAMPMRI-00006_1.3.6.1.4.1.14519.5.2.1.3671.4754.124813816937601110554342446480.dcm [Content-Type=application/dicom]...
# \
# Operation completed over 1 objects/1.1 MiB.
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/77f57ef3-6385-45e0-85d0-cbe0b484b0a5.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/b99b8ec6-8082-475e-b8ba-0e31b0a43a74.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/4d52f6d9-0d05-40c6-a8cf-700b9bcbc397.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/801e9ed3-297e-4523-b5ea-fd32faf2edaa.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/f5ffae17-b6e4-43a9-b5ab-42c096c131a4.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/f8842da6-3348-4a58-89f3-98a05d80d539.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/7e1a0892-ea63-48e3-8a0c-cc70488c0ec3.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/3564a829-c22c-4a6e-88cd-1e5c28b19843.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/48963933-01a5-45f6-a15f-9501ca217482.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/c7e89c13-02a5-45a8-bb63-6803419127f7.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/aded30c1-1723-489d-8d01-15a7e13ddf63.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/a1976454-6e70-4151-acf1-1ed761d8b92a.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/be516ab3-218f-43b9-906f-3f84cb58eb1e.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/a8e7a44c-b204-49e4-8827-d2102839a02c.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/841ee4b7-9e1a-4b5e-a635-8e6c809c08f8.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/c8f92085-0bca-426a-bfc3-78095015d503.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/908e52d7-40f4-4a4a-b120-0c4f1288f9db.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/676908a5-b00f-4bed-bdc0-d2c0a070c212.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/5515202d-7d64-427c-ae43-4315da03a5ba.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/5d707ae3-49fe-44cb-8cbe-b45ed1001d38.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/3fc5589a-7867-4a4d-a2af-16c2dca94612.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/0c2de0d4-d27c-44c5-ade2-7c0e996f80f9.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/7f0953ca-9e60-43e7-942f-8ab95de7b715.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/833a4dea-3ee3-4196-800b-9bb3a7de764b.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/81123ec2-359f-4df6-ae0c-a704873b3d71.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/633389ee-01a4-4629-b130-5d4f82f94a10.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/ff7c8df9-2d93-400f-9a69-6648e9873ffc.dcm...
# Copying gs://public-datasets-idc/69fe5c66-20ae-4263-8a48-c33d8a3b7587/12a9fb23-0831-4f30-a788-9f7e4ae92553.dcm...
# \ [28/28 files][ 14.1 MiB/ 14.1 MiB] 100% Done
# Operation completed over 28 objects/14.1 MiB.
# 100% 29/29 [00:00<00:00, 418.47it/s]
# Files sorted
# Serie processed : /content/prostateX/dicom/PCAMPMRI-00011/1.3.6.1.4.1.14519.5.2.1.3671.4754.131608903441424620949571415524/1.3.6.1.4.1.14519.5.2.1.3671.4754.212083125906384321957172108223
# SeriesDescription : T2 Weighted Axial
# Modality : MR
# Chris Rorden's dcm2niiX version v1.0.20220505  GCC9.4.0 x86-64 (64-bit Linux)
# Found 28 DICOM file(s)
# Convert 28 DICOM as /content/prostateX/nii/PCAMPMRI-00011_1.3.6.1.4.1.14519.5.2.1.3671.4754.212083125906384321957172108223 (512x512x28x1)
# Conversion required 1.139078 seconds (1.138886 for core code).
#
#
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# using model stored in  /content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1
# This model expects 1 input modalities for each image
# Found 1 unique case ids, here are some examples: ['PCAMPMRI-00011_1.3.6.1.4.1.14519.5.2.1.3671.4754.212083125906384321957172108223']
# If they don't look right, make sure to double check your filenames. They must end with _0000.nii.gz etc
# number of cases: 1
# number of cases that still need to be predicted: 1
# emptying cuda cache
# loading parameters for folds, None
# folds is None so we will automatically look for output folders (not using 'all'!)
# found the following folds:  ['/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_0', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_1', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_2', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_3', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_4']
# 2023-05-15 07:05:32.565493: Using dummy2d data augmentation
# using the following model files:  ['/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_0/model_final_checkpoint.model', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_1/model_final_checkpoint.model', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_2/model_final_checkpoint.model', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_3/model_final_checkpoint.model', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_4/model_final_checkpoint.model']
# starting preprocessing generator
# starting prediction...
# preprocessing /content/nnUNet/output/preds/PCAMPMRI-00011_1.3.6.1.4.1.14519.5.2.1.3671.4754.212083125906384321957172108223.nii.gz
# using preprocessor GenericPreprocessor
# before crop: (1, 28, 512, 512) after crop: (1, 28, 512, 512) spacing: [3.5        0.27340001 0.27340001]
#
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([3.5       , 0.27340001, 0.27340001]), 'spacing_transposed': array([3.5       , 0.27340001, 0.27340001]), 'data.shape (data is transposed)': (1, 28, 512, 512)}
# after:  {'spacing': array([2.20004711, 0.61250001, 0.61250001]), 'data.shape (data is resampled)': (1, 45, 229, 229)}
#
# (1, 45, 229, 229)
# This worker has ended successfully, no errors to report
# predicting /content/nnUNet/output/preds/PCAMPMRI-00011_1.3.6.1.4.1.14519.5.2.1.3671.4754.212083125906384321957172108223.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 45, 256, 256)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 8, 17], [0], [0]]
# number of tiles: 3
# computing Gaussian
# done
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 45, 256, 256)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 8, 17], [0], [0]]
# number of tiles: 3
# using precomputed Gaussian
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 45, 256, 256)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 8, 17], [0], [0]]
# number of tiles: 3
# using precomputed Gaussian
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 45, 256, 256)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 8, 17], [0], [0]]
# number of tiles: 3
# using precomputed Gaussian
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 45, 256, 256)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 8, 17], [0], [0]]
# number of tiles: 3
# using precomputed Gaussian
# prediction done
# inference done. Now waiting for the segmentation export to finish...
# force_separate_z: None interpolation order: 1
# separate z: True lowres axis [0]
# separate z, order in z is 0 order inplane is 1
# postprocessing...
# search path for T2 : /content/prostateX/nii/PCAMPMRI-00011_1.3.6.1.4.1.14519.5.2.1.3671.4754.212083125906384321957172108223*.nii.gz
# T2_path found : /content/prostateX/nii/PCAMPMRI-00011_1.3.6.1.4.1.14519.5.2.1.3671.4754.212083125906384321957172108223.nii.gz
# pred path : /content/nnUNet/output/preds/PCAMPMRI-00011_1.3.6.1.4.1.14519.5.2.1.3671.4754.212083125906384321957172108223.nii.gz
# /content/nnUNet/output/preds_processed/PCAMPMRI-00011_1.3.6.1.4.1.14519.5.2.1.3671.4754.212083125906384321957172108223.nii.gz
# Input path : /content/nnUNet/output/preds/PCAMPMRI-00011_1.3.6.1.4.1.14519.5.2.1.3671.4754.212083125906384321957172108223.nii.gz
# Output path : /content/nnUNet/output/preds_processed/PCAMPMRI-00011_1.3.6.1.4.1.14519.5.2.1.3671.4754.212083125906384321957172108223.nii.gz
# Number of components found : 2
#
#
# Converting...
# pred nnunet processed : /content/nnUNet/output/preds_resampled/PCAMPMRI-00011_1.3.6.1.4.1.14519.5.2.1.3671.4754.212083125906384321957172108223_resampled.nii.gz
# t2_dcm_folder : /content/prostateX/dicom/PCAMPMRI-00011/1.3.6.1.4.1.14519.5.2.1.3671.4754.131608903441424620949571415524/1.3.6.1.4.1.14519.5.2.1.3671.4754.212083125906384321957172108223
# dcmqi repository URL: git@github.com:QIICR/dcmqi.git revision: 1153738 tag: v1.2.5
# Loaded segmentation from /content/nnUNet/output/preds_resampled/PCAMPMRI-00011_1.3.6.1.4.1.14519.5.2.1.3671.4754.212083125906384321957172108223_resampled.nii.gz
# Searching recursively /content/prostateX/dicom/PCAMPMRI-00011/1.3.6.1.4.1.14519.5.2.1.3671.4754.131608903441424620949571415524/1.3.6.1.4.1.14519.5.2.1.3671.4754.212083125906384321957172108223 for DICOM files
# W: CodeValue (0008,0100) empty in CodeSequenceMacro (type 1C)
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.195335317117008832810829309410 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.115152053905953498250972011251 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.224634171104654013322629010729 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.331086178711305815501774904662 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.368608551823553577042396067495 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.171542177124864338303246288876 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.238544738880552239042428303552 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.335684863408018478498667136576 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.134369489605031559189945942780 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.183366610511818532333675002801 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.314458385584748362692214209526 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.260833522787355222136972718541 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.630312341246453214901630706289 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.170605705240603929514907552403 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.192521505540027678732413163820 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.140494244147846136699326872329 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.549529505259344541439023244874 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.715485128130001859343644785247 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.222430210344221940461812916218 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.230825707174103867145161291216 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.273986924561663529302998459455 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.170431292156640898716115655168 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.116121812054065742940494944281 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.212978868842877143677145644680 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.460262489730542258632270848885 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.221736398868740031720059234740 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.836378056768118916908039238862 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.196925737323173438611690521338 mapped
# 28 of 28 slices mapped to source DICOM images
# Found 2 label(s)
# Processing label 1
# Total non-empty slices that will be encoded in SEG for label 1 is 28
#  (inclusive from 0 to 28)
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Saved segmentation as /content/nnUNet/output/preds_resampled_dcm/PCAMPMRI-00011_1.3.6.1.4.1.14519.5.2.1.3671.4754.212083125906384321957172108223.dcm
# Done!
# Copying file:///content/nnUNet/output/preds_resampled_dcm/PCAMPMRI-00011_1.3.6.1.4.1.14519.5.2.1.3671.4754.212083125906384321957172108223.dcm [Content-Type=application/dicom]...
# |
# Operation completed over 1 objects/917.2 KiB.
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/220caa93-1f94-4ed3-977d-909f58d39b38.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/c209e457-11ec-4be8-8116-82598c394159.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/9fe42c82-273e-4833-8482-b89715a261b6.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/11a53dc9-8f2a-48ed-8c3a-2ff98689ef5c.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/53c49e11-0154-405c-a202-dbfa6cd11ae4.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/717a6083-e80e-4d9a-92b8-b5bc65b57d53.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/df945239-9cea-45dd-ab24-e4937aae47ff.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/34fd2dcd-14d6-41a6-a1ba-d61674540874.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/5e679f5c-088d-4da3-a8a3-e8d9e71bc804.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/44fb7989-0375-4770-9aab-ba2138488337.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/360ca1df-3d08-4dea-a468-41ffb1d229b8.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/2b15c5a0-5908-4f01-8361-41fac8b22478.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/e07b9cf4-ab1f-438c-9e44-d66385a65127.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/502e75a4-3416-40d6-99a2-deeed96f23a0.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/38b2cfba-d669-43b9-826a-838123744a26.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/441fffd8-de91-449c-b14a-84b8b3a95b52.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/e4a80475-1b70-4a02-bb55-81510c9794f9.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/69061dad-1a14-4c36-9dda-4fb29d273e93.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/34ba1949-57b8-4cd5-8096-05a373b7ef24.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/5d2666ff-55a4-41eb-87b5-467626327843.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/fd58c426-5c18-4669-aeb1-3d39b6ba8dae.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/7517aad0-697f-4249-aec6-6326b2c2d3e1.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/f39f21e7-c0dd-48b3-ac61-2fc7e4a5b4d1.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/87814176-27db-4112-a8f8-6278ff84bf69.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/b4b9cdee-2e53-4fdf-bcde-0ce9ddbac528.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/5aeb36ab-2702-4b9f-9277-658721710a36.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/c50bd184-c1f9-4c03-96f1-da949f0a74e4.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/e24f693b-aaab-41b3-a821-d232e59996ad.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/2bd9b6c8-9a59-41f3-b412-6cd0d5687bdd.dcm...
# Copying gs://public-datasets-idc/f39541cc-e0e4-4f89-9724-bb6e0ef79280/917cb1fa-335c-4c29-998d-4789637fd0f0.dcm...
# | [30/30 files][ 15.1 MiB/ 15.1 MiB] 100% Done   2.0 MiB/s ETA 00:00:00
# Operation completed over 30 objects/15.1 MiB.
# 100% 31/31 [00:00<00:00, 444.69it/s]
# Files sorted
# Serie processed : /content/prostateX/dicom/PCAMPMRI-00007/1.3.6.1.4.1.14519.5.2.1.3671.4754.962865348146140991373362412648/1.3.6.1.4.1.14519.5.2.1.3671.4754.330807155674174304012309699936
# SeriesDescription : T2 Weighted Axial
# Modality : MR
# Chris Rorden's dcm2niiX version v1.0.20220505  GCC9.4.0 x86-64 (64-bit Linux)
# Found 30 DICOM file(s)
# Convert 30 DICOM as /content/prostateX/nii/PCAMPMRI-00007_1.3.6.1.4.1.14519.5.2.1.3671.4754.330807155674174304012309699936 (512x512x30x1)
# Conversion required 0.985595 seconds (0.985323 for core code).
#
#
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# using model stored in  /content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1
# This model expects 1 input modalities for each image
# Found 1 unique case ids, here are some examples: ['PCAMPMRI-00007_1.3.6.1.4.1.14519.5.2.1.3671.4754.330807155674174304012309699936']
# If they don't look right, make sure to double check your filenames. They must end with _0000.nii.gz etc
# number of cases: 1
# number of cases that still need to be predicted: 1
# emptying cuda cache
# loading parameters for folds, None
# folds is None so we will automatically look for output folders (not using 'all'!)
# found the following folds:  ['/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_0', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_1', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_2', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_3', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_4']
# 2023-05-15 07:06:28.575869: Using dummy2d data augmentation
# using the following model files:  ['/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_0/model_final_checkpoint.model', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_1/model_final_checkpoint.model', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_2/model_final_checkpoint.model', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_3/model_final_checkpoint.model', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_4/model_final_checkpoint.model']
# starting preprocessing generator
# starting prediction...
# preprocessing /content/nnUNet/output/preds/PCAMPMRI-00007_1.3.6.1.4.1.14519.5.2.1.3671.4754.330807155674174304012309699936.nii.gz
# using preprocessor GenericPreprocessor
# before crop: (1, 30, 512, 512) after crop: (1, 30, 504, 512) spacing: [2.99981904 0.3125     0.3125    ]
#
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([2.99981904, 0.3125    , 0.3125    ]), 'spacing_transposed': array([2.99981904, 0.3125    , 0.3125    ]), 'data.shape (data is transposed)': (1, 30, 504, 512)}
# after:  {'spacing': array([2.20004711, 0.61250001, 0.61250001]), 'data.shape (data is resampled)': (1, 41, 257, 261)}
#
# (1, 41, 257, 261)
# This worker has ended successfully, no errors to report
# predicting /content/nnUNet/output/preds/PCAMPMRI-00007_1.3.6.1.4.1.14519.5.2.1.3671.4754.330807155674174304012309699936.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 41, 257, 261)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 13], [0, 1], [0, 5]]
# number of tiles: 8
# computing Gaussian
# done
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 41, 257, 261)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 13], [0, 1], [0, 5]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 41, 257, 261)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 13], [0, 1], [0, 5]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 41, 257, 261)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 13], [0, 1], [0, 5]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 41, 257, 261)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 13], [0, 1], [0, 5]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# inference done. Now waiting for the segmentation export to finish...
# force_separate_z: None interpolation order: 1
# separate z: True lowres axis [0]
# separate z, order in z is 0 order inplane is 1
# postprocessing...
# search path for T2 : /content/prostateX/nii/PCAMPMRI-00007_1.3.6.1.4.1.14519.5.2.1.3671.4754.330807155674174304012309699936*.nii.gz
# T2_path found : /content/prostateX/nii/PCAMPMRI-00007_1.3.6.1.4.1.14519.5.2.1.3671.4754.330807155674174304012309699936.nii.gz
# pred path : /content/nnUNet/output/preds/PCAMPMRI-00007_1.3.6.1.4.1.14519.5.2.1.3671.4754.330807155674174304012309699936.nii.gz
# /content/nnUNet/output/preds_processed/PCAMPMRI-00007_1.3.6.1.4.1.14519.5.2.1.3671.4754.330807155674174304012309699936.nii.gz
# Input path : /content/nnUNet/output/preds/PCAMPMRI-00007_1.3.6.1.4.1.14519.5.2.1.3671.4754.330807155674174304012309699936.nii.gz
# Output path : /content/nnUNet/output/preds_processed/PCAMPMRI-00007_1.3.6.1.4.1.14519.5.2.1.3671.4754.330807155674174304012309699936.nii.gz
# Number of components found : 2
#
#
# Converting...
# pred nnunet processed : /content/nnUNet/output/preds_resampled/PCAMPMRI-00007_1.3.6.1.4.1.14519.5.2.1.3671.4754.330807155674174304012309699936_resampled.nii.gz
# t2_dcm_folder : /content/prostateX/dicom/PCAMPMRI-00007/1.3.6.1.4.1.14519.5.2.1.3671.4754.962865348146140991373362412648/1.3.6.1.4.1.14519.5.2.1.3671.4754.330807155674174304012309699936
# dcmqi repository URL: git@github.com:QIICR/dcmqi.git revision: 1153738 tag: v1.2.5
# Loaded segmentation from /content/nnUNet/output/preds_resampled/PCAMPMRI-00007_1.3.6.1.4.1.14519.5.2.1.3671.4754.330807155674174304012309699936_resampled.nii.gz
# Searching recursively /content/prostateX/dicom/PCAMPMRI-00007/1.3.6.1.4.1.14519.5.2.1.3671.4754.962865348146140991373362412648/1.3.6.1.4.1.14519.5.2.1.3671.4754.330807155674174304012309699936 for DICOM files
# W: CodeValue (0008,0100) empty in CodeSequenceMacro (type 1C)
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.345034594562928837224864826912 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.677264100325159590527270860523 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.308027140480537869835692253826 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.419322767929342923473470344493 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.228564420788640680199782640302 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.321585027980650347490784340150 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.835931381869963572251041974065 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.146296889906316807380264881010 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.556991203369676359696758487816 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.492681626124695211179509692116 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.185616230065056400370605559896 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.185800883861362488183196340200 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.198504360696065106187433487495 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.199296776077299642347009338996 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.138156517245823887151856637969 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.222761149488717199417649525424 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.337117142514063364344602328010 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.120582234154181092938198014730 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.115468310496457922075134276709 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.336469780736937198229647047524 mapped
# ...
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.208088172937147032455723858054 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.193539593820130889961405268548 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.321870096289915672618443203229 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.316340860531831215290625427972 mapped
# 28 of 28 slices mapped to source DICOM images
# Found 2 label(s)
# Processing label 1
# Total non-empty slices that will be encoded in SEG for label 1 is 28
#  (inclusive from 0 to 28)
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Saved segmentation as /content/nnUNet/output/preds_resampled_dcm/PCAMPMRI-00010_1.3.6.1.4.1.14519.5.2.1.3671.4754.218938411300600171613807256501.dcm
# Done!
# Copying file:///content/nnUNet/output/preds_resampled_dcm/PCAMPMRI-00010_1.3.6.1.4.1.14519.5.2.1.3671.4754.218938411300600171613807256501.dcm [Content-Type=application/dicom]...
# \
# Operation completed over 1 objects/917.2 KiB.
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/494b42e1-ba20-49e5-a3f1-6d043704dca1.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/19dd57cc-0169-48ab-9cf7-29d125fccb4a.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/2ba00c8e-721b-4417-b2e5-e106ea236eeb.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/f0e2d2f0-4bc0-4ef8-b279-1a79c9323302.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/d4371e75-7afc-4b02-8126-edf41a46c5bf.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/2f645aac-f8fe-4545-98ed-9a56ab6b952d.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/f5f65e41-7ae8-4a81-8219-c606991196ab.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/b8d0e3c6-bb37-465e-880e-f06b3033268d.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/e4883a93-49ad-4734-9186-5809e46d0915.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/75c89623-75aa-4b2d-898e-c6ab705637e7.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/c81446e8-6dde-43e2-9cc0-831f67585f52.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/cf098486-90f8-49af-9cd9-bb1c05934250.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/c2f38fe7-75c3-4f08-810f-d3ec45260d7a.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/6a99d190-c868-4268-b91f-c5c62545d7f1.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/f2a52e7d-2366-4262-a89d-3bedefab5efc.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/699ae1da-256d-4bbc-9ac0-366e821ba607.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/886d675d-0840-4240-aaa2-6dbb3cd6cb1b.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/a2798052-90f8-4849-9b80-33c624c3e0af.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/f6fdd980-4bd0-472a-a876-588a147d157a.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/fe19709e-3ad1-4437-8458-ea70343869ec.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/3a3a44eb-7e21-47fd-8350-02c34ccf77d2.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/6d03a27f-842d-48bf-98f3-c310e9ced72d.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/470f0ca8-853e-4883-82f7-b2143093d970.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/8aa10d51-5f3b-45f4-b2d5-05222cff59b3.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/c4b982d7-2b56-495e-b518-ab6044babbac.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/b55fbb6c-4d58-43d7-b4df-add84bf91959.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/b8854a21-d8e4-4a70-aa71-8be6c28bfa68.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/1c8a4aa4-8bde-4cf2-8a37-fe147e53e37d.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/3f1819ca-79ca-489e-a7f5-a72deaa8df2c.dcm...
# Copying gs://public-datasets-idc/0c341066-954b-4076-aa9d-aef460b6ab12/1eedd2a6-e262-4edb-97ff-9ed506733ce0.dcm...
# \ [30/30 files][ 15.1 MiB/ 15.1 MiB] 100% Done   2.1 MiB/s ETA 00:00:00
# Operation completed over 30 objects/15.1 MiB.
# 100% 31/31 [00:00<00:00, 437.61it/s]
# Files sorted
# Serie processed : /content/prostateX/dicom/PCAMPMRI-00003/1.3.6.1.4.1.14519.5.2.1.3671.4754.162322077241419864654545266845/1.3.6.1.4.1.14519.5.2.1.3671.4754.165941479363091869002475812419
# SeriesDescription : T2 Weighted Axial
# Modality : MR
# Chris Rorden's dcm2niiX version v1.0.20220505  GCC9.4.0 x86-64 (64-bit Linux)
# Found 30 DICOM file(s)
# Convert 30 DICOM as /content/prostateX/nii/PCAMPMRI-00003_1.3.6.1.4.1.14519.5.2.1.3671.4754.165941479363091869002475812419 (512x512x30x1)
# Conversion required 1.009467 seconds (1.008861 for core code).
#
#
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# using model stored in  /content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1
# This model expects 1 input modalities for each image
# Found 1 unique case ids, here are some examples: ['PCAMPMRI-00003_1.3.6.1.4.1.14519.5.2.1.3671.4754.165941479363091869002475812419']
# If they don't look right, make sure to double check your filenames. They must end with _0000.nii.gz etc
# number of cases: 1
# number of cases that still need to be predicted: 1
# emptying cuda cache
# loading parameters for folds, None
# folds is None so we will automatically look for output folders (not using 'all'!)
# found the following folds:  ['/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_0', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_1', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_2', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_3', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_4']
# 2023-05-15 07:29:24.816215: Using dummy2d data augmentation
# using the following model files:  ['/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_0/model_final_checkpoint.model', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_1/model_final_checkpoint.model', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_2/model_final_checkpoint.model', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_3/model_final_checkpoint.model', '/content/nnUNet/output/preds/nnUNet/3d_fullres/Task024_Promise/nnUNetTrainerV2__nnUNetPlansv2.1/fold_4/model_final_checkpoint.model']
# starting preprocessing generator
# starting prediction...
# preprocessing /content/nnUNet/output/preds/PCAMPMRI-00003_1.3.6.1.4.1.14519.5.2.1.3671.4754.165941479363091869002475812419.nii.gz
# using preprocessor GenericPreprocessor
# before crop: (1, 30, 512, 512) after crop: (1, 30, 504, 512) spacing: [3.00015402 0.3125     0.3125    ]
#
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([3.00015402, 0.3125    , 0.3125    ]), 'spacing_transposed': array([3.00015402, 0.3125    , 0.3125    ]), 'data.shape (data is transposed)': (1, 30, 504, 512)}
# after:  {'spacing': array([2.20004711, 0.61250001, 0.61250001]), 'data.shape (data is resampled)': (1, 41, 257, 261)}
#
# (1, 41, 257, 261)
# This worker has ended successfully, no errors to report
# predicting /content/nnUNet/output/preds/PCAMPMRI-00003_1.3.6.1.4.1.14519.5.2.1.3671.4754.165941479363091869002475812419.nii.gz
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 41, 257, 261)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 13], [0, 1], [0, 5]]
# number of tiles: 8
# computing Gaussian
# done
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 41, 257, 261)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 13], [0, 1], [0, 5]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 41, 257, 261)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 13], [0, 1], [0, 5]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 41, 257, 261)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 13], [0, 1], [0, 5]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (1, 41, 257, 261)
# patch size: [ 28 256 256]
# steps (x, y, and z): [[0, 13], [0, 1], [0, 5]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# inference done. Now waiting for the segmentation export to finish...
# force_separate_z: None interpolation order: 1
# separate z: True lowres axis [0]
# separate z, order in z is 0 order inplane is 1
# postprocessing...
# search path for T2 : /content/prostateX/nii/PCAMPMRI-00003_1.3.6.1.4.1.14519.5.2.1.3671.4754.165941479363091869002475812419*.nii.gz
# T2_path found : /content/prostateX/nii/PCAMPMRI-00003_1.3.6.1.4.1.14519.5.2.1.3671.4754.165941479363091869002475812419.nii.gz
# pred path : /content/nnUNet/output/preds/PCAMPMRI-00003_1.3.6.1.4.1.14519.5.2.1.3671.4754.165941479363091869002475812419.nii.gz
# /content/nnUNet/output/preds_processed/PCAMPMRI-00003_1.3.6.1.4.1.14519.5.2.1.3671.4754.165941479363091869002475812419.nii.gz
# Input path : /content/nnUNet/output/preds/PCAMPMRI-00003_1.3.6.1.4.1.14519.5.2.1.3671.4754.165941479363091869002475812419.nii.gz
# Output path : /content/nnUNet/output/preds_processed/PCAMPMRI-00003_1.3.6.1.4.1.14519.5.2.1.3671.4754.165941479363091869002475812419.nii.gz
# Number of components found : 2
#
#
# Converting...
# pred nnunet processed : /content/nnUNet/output/preds_resampled/PCAMPMRI-00003_1.3.6.1.4.1.14519.5.2.1.3671.4754.165941479363091869002475812419_resampled.nii.gz
# t2_dcm_folder : /content/prostateX/dicom/PCAMPMRI-00003/1.3.6.1.4.1.14519.5.2.1.3671.4754.162322077241419864654545266845/1.3.6.1.4.1.14519.5.2.1.3671.4754.165941479363091869002475812419
# dcmqi repository URL: git@github.com:QIICR/dcmqi.git revision: 1153738 tag: v1.2.5
# Loaded segmentation from /content/nnUNet/output/preds_resampled/PCAMPMRI-00003_1.3.6.1.4.1.14519.5.2.1.3671.4754.165941479363091869002475812419_resampled.nii.gz
# Searching recursively /content/prostateX/dicom/PCAMPMRI-00003/1.3.6.1.4.1.14519.5.2.1.3671.4754.162322077241419864654545266845/1.3.6.1.4.1.14519.5.2.1.3671.4754.165941479363091869002475812419 for DICOM files
# W: CodeValue (0008,0100) empty in CodeSequenceMacro (type 1C)
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.727281738416127185010980949175 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.288689548764288881958144940028 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.136853673300636100084824564755 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.323995730445362242995087371768 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.673117188065527460445731666179 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.113247142789721787569760116480 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.155446640498718003430826719810 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.518726510674492747955500664567 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.239499427228625166381682671154 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.298201210425497233456084622538 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.191869188193025309293126301886 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.268002131836610540395165779977 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.112238133887171353177474655924 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.744545346875230710562305723111 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.173942856461151294209955452804 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.100165068464266285086841310345 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.119300735065878202674092971205 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.242594266871554105038299506978 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.266757773615564724328466404245 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.218180757722251444487079686688 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.261830331510534509118184174072 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.295602873052022351027112769420 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.947225803882645051438090984523 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.244234462477607928188882741452 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.242877588125565737806889167245 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.185205075445282018526039419087 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.256011529773465746047980387391 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.213839354625747760050074874720 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.978087335058434026528477380594 mapped
# SOPInstanceUID1.3.6.1.4.1.14519.5.2.1.3671.4754.162850838343386434729166706126 mapped
# 30 of 30 slices mapped to source DICOM images
# Found 2 label(s)
# Processing label 1
# Total non-empty slices that will be encoded in SEG for label 1 is 30
#  (inclusive from 0 to 30)
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Added source image item
# Saved segmentation as /content/nnUNet/output/preds_resampled_dcm/PCAMPMRI-00003_1.3.6.1.4.1.14519.5.2.1.3671.4754.165941479363091869002475812419.dcm
# Done!
# Copying file:///content/nnUNet/output/preds_resampled_dcm/PCAMPMRI-00003_1.3.6.1.4.1.14519.5.2.1.3671.4754.165941479363091869002475812419.dcm [Content-Type=application/dicom]...
# \
# Operation completed over 1 objects/982.6 KiB.
