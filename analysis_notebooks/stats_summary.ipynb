# %% [markdown]
# # Functions

# %%
def add_missing_PID_df(orig_df, model_df):
  unique_PID_cases = orig_df.PID.unique()
  out_df = model_df.copy()
  for PID_current in unique_PID_cases:
    if PID_current not in model_df.PID.unique():
      #retrieve metadata from orig_df
      orig_caseID_serie = orig_df[orig_df["PID"] == PID_current].head(1).squeeze()
      #overwrite values with volume=0mL
      orig_caseID_serie["ai_Value"] = 0
      orig_caseID_serie["SegmentAlgorithmName"] = model_df.SegmentAlgorithmName.unique()[0]
      #add to current model_df
      out_df = pd.concat([out_df, pd.DataFrame([orig_caseID_serie])],
                           ignore_index=True)
  return out_df

# %%
def calculate_time_index(row, df_input, studyDateColName="image_StudyDate"): #assumes only two studies per PatientID
  other_study_time = df_input[(df_input["image_PatientID"] == row["image_PatientID"])
    & (df_input["StudyInstanceUID"] != row["StudyInstanceUID"])][studyDateColName].values[0]
  if row[studyDateColName] < other_study_time:
    return "T0"
  elif row[studyDateColName] > other_study_time:
    return "T1"
  else:
    return "T"

# %%
def calculate_time_index_prostatex_inf_only(row, df_input,
                         seriesTimecolName="image_SeriesTime"): #assumes only two studies per PatientID
  seriesTimesLst = df_input[(df_input["image_PatientID"] == row["image_PatientID"])
    & (df_input["StudyInstanceUID"] == row["StudyInstanceUID"])][seriesTimecolName].unique()
  for idx, el in enumerate(sorted(seriesTimesLst)):
    if el == row[seriesTimecolName]:
      return f"T{idx}"

# %% [markdown]
# # Imports

# %%
import os
import numpy as np
import glob
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from statsmodels.stats.multitest import multipletests

# %%
import plotly.graph_objects as go
import plotly.express as px
# import colorcet as cc
import os
import plotly.io as pio

# %%
# #colab
# from google.colab import auth
# auth.authenticate_user()
# project_id = "idc-sandbox-003"
# os.environ["GCP_PROJECT_ID"] = project_id
# from google.cloud import bigquery
# bq_client = bigquery.Client(os.environ["GCP_PROJECT_ID"])

# %% [markdown]
# # Data import

# %%
# selection_query = f"""
# SELECT *
# FROM `idc-sandbox-003.prostate_seg_terra_mhub_v3.final_table_looker_studio`
#  """
# selection_result = bq_client.query(selection_query)
# data_new_df = selection_result.result().to_dataframe()
# data_new_df["algorithmNameCollection"] = data_new_df.apply(lambda x : x["SegmentAlgorithmName"]+"-"+x["collection_id"], axis=1)
# !wget https://raw.githubusercontent.com/ImagingDataCommons/idc-prostate-mri-analysis/refs/heads/main/analysis_results/analysis_results.csv -O analysis_results.csv
data_new_df = pd.read_csv("analysis_results.csv")

data_new_df["ai_Value"] = data_new_df.apply(lambda x : x["ai_Value"]/1000 if x["ai_Value"] is not None else None, axis=1)
data_new_df["expert_Value"] = data_new_df.apply(lambda x : x["expert_Value"]/1000 if x["expert_Value"] is not None else None, axis=1)
# Out:
# --2024-11-08 15:38:21--  https://raw.githubusercontent.com/ccosmin97/idc-prostate-mri-analysis/refs/heads/main/analysis_results.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7256924 (6.9M) [text/plain]
# Saving to: ‘analysis_results.csv’
#
# analysis_results.cs 100%[===================>]   6.92M  --.-KB/s    in 0.09s
#
# 2024-11-08 15:38:22 (73.3 MB/s) - ‘analysis_results.csv’ saved [7256924/7256924]

# %%
data_new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4909 entries, 0 to 4908
# Data columns (total 61 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   segmentationInstanceUID               4907 non-null   object
#  1   sourceSegmentedSeriesUID              4907 non-null   object
#  2   expert_QuantityCodeMeaning            4909 non-null   object
#  3   expert_QuantityCodeValue              4909 non-null   object
#  4   expert_Value                          4909 non-null   float64
#  5   expert_UnitsCodeValue                 4909 non-null   object
#  6   expert_UnitsCodeMeaning               4909 non-null   object
#  7   expert_findingSiteCodeValue           4909 non-null   object
#  8   expert_findingSiteCodeMeaning         4909 non-null   object
#  9   ai_QuantityCodeMeaning                4907 non-null   object
#  10  ai_QuantityCodeValue                  4907 non-null   object
#  11  ai_QuantityCodingSchemeDesignator     4907 non-null   object
#  12  ai_Value                              4907 non-null   float64
#  13  ai_UnitsCodeValue                     4907 non-null   object
#  14  ai_UnitsCodeMeaning                   4907 non-null   object
#  15  ai_findingSiteCodeValue               4907 non-null   float64
#  16  ai_findingSiteCodeMeaning             4907 non-null   object
#  17  StudyInstanceUID                      4909 non-null   object
#  18  SeriesInstanceUID                     4909 non-null   object
#  19  SegmentedPropertyCategoryCodeValue    4909 non-null   int64
#  20  SegmentedPropertyCategoryCodeMeaning  4909 non-null   object
#  21  SegmentedPropertyTypeCodeValue        4909 non-null   int64
#  22  SegmentedPropertyTypeCodeMeaning      4909 non-null   object
#  23  SegmentAlgorithmType                  4909 non-null   object
#  24  SegmentNumber                         4909 non-null   int64
#  25  segmented_SeriesInstanceUID           4909 non-null   object
#  26  expert_measurements_SOPInstanceUID    4909 non-null   object
#  27  segmentation_SOPInstanceUID           4909 non-null   object
#  28  refSerieUID                           4909 non-null   object
#  29  ai_seg_serieUID                       4909 non-null   object
#  30  idc_seg_serieUID                      4909 non-null   object
#  31  aiSegmentNumber                       4909 non-null   int64
#  32  idcSegmentNumber                      4909 non-null   int64
#  33  idcSegmentCodeMeaning                 4909 non-null   object
#  34  aiSegmentCodeMeaning                  4909 non-null   object
#  35  aiSegmentCodeValue                    4909 non-null   int64
#  36  idcSegmentCodeValue                   4909 non-null   object
#  37  aiSegmentCodingScheme                 4909 non-null   object
#  38  idcSegmentCodingScheme                4909 non-null   object
#  39  dsc                                   4909 non-null   float64
#  40  hsdff                                 4909 non-null   float64
#  41  hsdff_95                              4909 non-null   float64
#  42  tp                                    4909 non-null   int64
#  43  fp                                    4909 non-null   int64
#  44  tn                                    4909 non-null   int64
#  45  fn                                    4909 non-null   int64
#  46  collection_id                         4909 non-null   object
#  47  image_SeriesInstanceUID               4909 non-null   object
#  48  image_PixelSpacing                    4909 non-null   object
#  49  image_SliceThickness                  4909 non-null   float64
#  50  image_MagneticFieldStrength           4909 non-null   float64
#  51  image_SeriesDate                      4909 non-null   object
#  52  image_StudyDate                       4909 non-null   object
#  53  image_StudyDescription                4909 non-null   object
#  54  image_StudyDescription_1              4909 non-null   object
#  55  image_Manufacturer                    4909 non-null   object
#  56  image_ManufacturerModelName           4909 non-null   object
#  57  image_PatientID                       4909 non-null   object
#  58  SegmentAlgorithmName                  4909 non-null   object
#  59  ohif_url                              4909 non-null   object
#  60  algorithmNameCollection               4909 non-null   object
# dtypes: float64(8), int64(10), object(43)
# memory usage: 2.3+ MB

# %% [markdown]
# # Evaluation Statistics

# %% [markdown]
# ### Whole prostate quantitative analysis

# %%
data_new_df.collection_id.unique()
# Out:
# array(['prostatex', 'prostate_mri_us_biopsy',
#        'qin_prostate_repeatability'], dtype=object)

# %%
data_new_df.idcSegmentCodeMeaning.unique()
# Out:
# array(['Prostate', 'Peripheral_zone_of_prostate',
#        'Transition_zone_of_prostate', 'Peripheral_zone_of_the_prostate'],
#       dtype=object)

# %%
temp_df = data_new_df[data_new_df.SegmentedPropertyTypeCodeMeaning.isin(['Prostate', 'Prostatic structure'])]
len(temp_df)
# Out:
# 4459

# %%
temp2_df = data_new_df[data_new_df.idcSegmentCodeMeaning.isin(['Prostate'])]
len(temp2_df)
# Out:
# 4459

# %%
temp_df.collection_id.unique()
# Out:
# array(['prostatex', 'prostate_mri_us_biopsy',
#        'qin_prostate_repeatability'], dtype=object)

# %% [markdown]
# ProstateX

# %%
metrics_summary_prostatex = temp_df[temp_df["collection_id"]=="prostatex"].groupby('SegmentAlgorithmName').agg(
    mean_dice=('dsc', 'mean'),
    std_dice=('dsc', 'std'),
    min_dice=('dsc', 'min'),
    max_dice=('dsc', 'max'),
    mean_hausdorff95=('hsdff_95', 'mean'),
    std_hausdorff95=('hsdff_95', 'std'),
    min_hausdorff95=('hsdff_95', 'min'),
    max_hausdorff95=('hsdff_95', 'max'),
    mean_ai_volume=("ai_Value", "mean"),
    std_ai_volume=("ai_Value", "std"),
    min_ai_volume=('ai_Value', 'min'),
    max_ai_volume=('ai_Value', 'max'),
    mean_expert_volume=("expert_Value", "mean"),
    std_expert_volume=("expert_Value", "std"),
    min_expert_volume=('expert_Value', 'min'),
    max_expert_volume=('expert_Value', 'max'),
    num_samples=('dsc', 'size')  # Counting number of samples
).round(2).reset_index()

# %%
metrics_summary_prostatex
# Out:
#            SegmentAlgorithmName  mean_dice  std_dice  min_dice  max_dice  \
# 0       bamf_nnunet_mr_prostate       0.95      0.01      0.91      0.97
# 1             monai_prostate158       0.92      0.02      0.86      0.96
# 2        nnunet_prostate_task24       0.93      0.03      0.74      0.96
# 3  nnunet_prostate_zonal_task05       0.90      0.04      0.64      0.95
#
#    mean_hausdorff95  std_hausdorff95  min_hausdorff95  max_hausdorff95  \
# 0              0.30             0.28             0.00             1.50
# 1              0.92             0.41             0.25             2.50
# 2              0.90             0.91             0.00             8.13
# 3              1.69             1.46             0.35            12.20
#
#   mean_ai_volume  std_ai_volume min_ai_volume  max_ai_volume  \
# 0      67.710969          32.36  18.723625000  167.490781000
# 1      65.011331          30.70  19.729719000  161.858781000
# 2      67.971718          30.44  22.186250000  166.366906000
# 3      66.914626          30.10  20.170844000  163.664281000
#
#   mean_expert_volume  std_expert_volume min_expert_volume max_expert_volume  \
# 0          66.392519              32.11      17.599844000     167.920156000
# 1          66.392519              32.11      17.599844000     167.920156000
# 2          66.392519              32.11      17.599844000     167.920156000
# 3          66.392519              32.11      17.599844000     167.920156000
#
#    num_samples
# 0           98
# 1           98
# 2           98
# 3           98

# %% [markdown]
# QIN

# %%
metrics_summary_qin = temp_df[temp_df["collection_id"]=="qin_prostate_repeatability"].groupby('SegmentAlgorithmName').agg(
    mean_dice=('dsc', 'mean'),
    std_dice=('dsc', 'std'),
    min_dice=('dsc', 'min'),
    max_dice=('dsc', 'max'),
    mean_hausdorff95=('hsdff_95', 'mean'),
    std_hausdorff95=('hsdff_95', 'std'),
    min_hausdorff95=('hsdff_95', 'min'),
    max_hausdorff95=('hsdff_95', 'max'),
    mean_ai_volume=("ai_Value", "mean"),
    std_ai_volume=("ai_Value", "std"),
    min_ai_volume=('ai_Value', 'min'),
    max_ai_volume=('ai_Value', 'max'),
    mean_expert_volume=("expert_Value", "mean"),
    std_expert_volume=("expert_Value", "std"),
    min_expert_volume=('expert_Value', 'min'),
    max_expert_volume=('expert_Value', 'max'),
    num_samples=('dsc', 'size')  # Counting number of samples
).round(2).reset_index()

# %%
metrics_summary_qin
# Out:
#            SegmentAlgorithmName  mean_dice  std_dice  min_dice  max_dice  \
# 0       bamf_nnunet_mr_prostate       0.79      0.17      0.19      0.92
# 1             monai_prostate158       0.83      0.05      0.70      0.90
# 2        nnunet_prostate_task24       0.85      0.05      0.72      0.92
# 3  nnunet_prostate_zonal_task05       0.57      0.27      0.00      0.87
#
#    mean_hausdorff95  std_hausdorff95  min_hausdorff95  max_hausdorff95  \
# 0              4.73             4.74             0.62            18.18
# 1              3.55             2.38             1.50            12.07
# 2              2.60             1.93             1.09             9.98
# 3             14.82            12.88             1.81            56.11
#
#   mean_ai_volume  std_ai_volume min_ai_volume  max_ai_volume  \
# 0      39.983223          19.71   3.877832000   96.642958000
# 1      52.783244          29.91  23.120300000  124.452408000
# 2      54.373543          27.91  25.274320000  111.598841000
# 3       42.76282          22.83   0.169168000   88.113334000
#
#   mean_expert_volume  std_expert_volume min_expert_volume max_expert_volume  \
# 0          46.450388              28.11      19.038892000     115.874483000
# 1          46.450388              28.11      19.038892000     115.874483000
# 2          46.450388              28.11      19.038892000     115.874483000
# 3          46.450388              28.11      19.038892000     115.874483000
#
#    num_samples
# 0           30
# 1           30
# 2           30
# 3           30

# %% [markdown]
# Prostate-MRI-US-Biopsy

# %%
metrics_summary_prostate_mri_us_biopsy = temp_df[temp_df["collection_id"]=="prostate_mri_us_biopsy"].groupby('SegmentAlgorithmName').agg(
    mean_dice=('dsc', 'mean'),
    std_dice=('dsc', 'std'),
    min_dice=('dsc', 'min'),
    max_dice=('dsc', 'max'),
    mean_hausdorff95=('hsdff_95', 'mean'),
    std_hausdorff95=('hsdff_95', 'std'),
    min_hausdorff95=('hsdff_95', 'min'),
    max_hausdorff95=('hsdff_95', 'max'),
    mean_ai_volume=("ai_Value", "mean"),
    std_ai_volume=("ai_Value", "std"),
    min_ai_volume=('ai_Value', 'min'),
    max_ai_volume=('ai_Value', 'max'),
    mean_expert_volume=("expert_Value", "mean"),
    std_expert_volume=("expert_Value", "std"),
    min_expert_volume=('expert_Value', 'min'),
    max_expert_volume=('expert_Value', 'max'),
    num_samples=('dsc', 'size')  # Counting number of samples
).round(2).reset_index()

# %%
metrics_summary_prostate_mri_us_biopsy.head()
# Out:
#            SegmentAlgorithmName  mean_dice  std_dice  min_dice  max_dice  \
# 0       bamf_nnunet_mr_prostate       0.89      0.05      0.13      0.96
# 1             monai_prostate158       0.88      0.07      0.12      0.95
# 2        nnunet_prostate_task24       0.86      0.09      0.10      0.95
# 3  nnunet_prostate_zonal_task05       0.79      0.16      0.00      0.94
#
#    mean_hausdorff95  std_hausdorff95  min_hausdorff95  max_hausdorff95  \
# 0              1.54             1.66             0.00            24.93
# 1              1.77             2.61             0.33            34.99
# 2              2.94             6.53             0.33            56.04
# 3              9.17            14.33             0.47            63.17
#
#   mean_ai_volume  std_ai_volume min_ai_volume  max_ai_volume  \
# 0      50.928355          26.32  10.166936000  230.466186000
# 1      47.462448          24.06   8.067497000  193.951943000
# 2      51.524569          22.20  19.457620000  202.835437000
# 3      50.593193          22.60   7.370234000  215.524546000
#
#   mean_expert_volume  std_expert_volume min_expert_volume max_expert_volume  \
# 0          48.966954              26.11      10.563183000     222.405063000
# 1          48.958933              26.10      10.563183000     222.405063000
# 2          48.958933              26.10      10.563183000     222.405063000
# 3          48.958933              26.10      10.563183000     222.405063000
#
#    num_samples
# 0          986
# 1          987
# 2          987
# 3          987

# %% [markdown]
# ### Peripheral zone quantitative analysis

# %%
temp_df = data_new_df[data_new_df.SegmentedPropertyTypeCodeMeaning == 'Structure of peripheral glandular zone of prostate (body structure)']

# %%
metrics_summary_prostatex = temp_df[temp_df["collection_id"]=="prostatex"].groupby('SegmentAlgorithmName').agg(
    mean_dice=('dsc', 'mean'),
    std_dice=('dsc', 'std'),
    min_dice=('dsc', 'min'),
    max_dice=('dsc', 'max'),
    mean_hausdorff95=('hsdff_95', 'mean'),
    std_hausdorff95=('hsdff_95', 'std'),
    min_hausdorff95=('hsdff_95', 'min'),
    max_hausdorff95=('hsdff_95', 'max'),
    mean_ai_volume=("ai_Value", "mean"),
    std_ai_volume=("ai_Value", "std"),
    min_ai_volume=('ai_Value', 'min'),
    max_ai_volume=('ai_Value', 'max'),
    mean_expert_volume=("expert_Value", "mean"),
    std_expert_volume=("expert_Value", "std"),
    min_expert_volume=('expert_Value', 'min'),
    max_expert_volume=('expert_Value', 'max'),
    num_samples=('dsc', 'size')  # Counting number of samples
).round(2).reset_index()

# %%
metrics_summary_prostatex.head()
# Out:
#            SegmentAlgorithmName  mean_dice  std_dice  min_dice  max_dice  \
# 0             monai_prostate158       0.74      0.08      0.46      0.88
# 1  nnunet_prostate_zonal_task05       0.67      0.14      0.06      0.84
#
#    mean_hausdorff95  std_hausdorff95  min_hausdorff95  max_hausdorff95  \
# 0              3.27             1.88             1.21            12.79
# 1              4.81             3.18             1.50            20.07
#
#   mean_ai_volume  std_ai_volume min_ai_volume max_ai_volume  \
# 0      14.661519           5.30   5.763938000  33.002906000
# 1      12.938248           4.94   0.796156000  31.919719000
#
#   mean_expert_volume  std_expert_volume min_expert_volume max_expert_volume  \
# 0          19.779091               6.98       6.547250000      42.050969000
# 1          19.799546               7.01       6.547250000      42.050969000
#
#    num_samples
# 0           98
# 1           97

# %%
metrics_summary_qin = temp_df[temp_df["collection_id"]=="qin_prostate_repeatability"].groupby('SegmentAlgorithmName').agg(
    mean_dice=('dsc', 'mean'),
    std_dice=('dsc', 'std'),
    min_dice=('dsc', 'min'),
    max_dice=('dsc', 'max'),
    mean_hausdorff95=('hsdff_95', 'mean'),
    std_hausdorff95=('hsdff_95', 'std'),
    min_hausdorff95=('hsdff_95', 'min'),
    max_hausdorff95=('hsdff_95', 'max'),
    mean_ai_volume=("ai_Value", "mean"),
    std_ai_volume=("ai_Value", "std"),
    min_ai_volume=('ai_Value', 'min'),
    max_ai_volume=('ai_Value', 'max'),
    mean_expert_volume=("expert_Value", "mean"),
    std_expert_volume=("expert_Value", "std"),
    min_expert_volume=('expert_Value', 'min'),
    max_expert_volume=('expert_Value', 'max'),
    num_samples=('dsc', 'size')  # Counting number of samples
).round(2).reset_index()

# %%
metrics_summary_qin.head()
# Out:
#            SegmentAlgorithmName  mean_dice  std_dice  min_dice  max_dice  \
# 0             monai_prostate158       0.65      0.16      0.15      0.79
# 1  nnunet_prostate_zonal_task05       0.39      0.30      0.00      0.80
#
#    mean_hausdorff95  std_hausdorff95  min_hausdorff95  max_hausdorff95  \
# 0              5.48             4.56             1.88            20.88
# 1             18.37            23.40             2.49            97.66
#
#   mean_ai_volume  std_ai_volume min_ai_volume max_ai_volume  \
# 0      11.147744           3.15   5.128125000  17.695422000
# 1       6.754592           5.51   0.005930000  15.105507000
#
#   mean_expert_volume  std_expert_volume min_expert_volume max_expert_volume  \
# 0             9.8965               3.98       3.202537000      18.637438000
# 1          10.063348               3.94       3.202537000      18.637438000
#
#    num_samples
# 0           30
# 1           29

# %% [markdown]
# ### Transition zone quantitative analysis

# %%
temp_df = data_new_df[data_new_df.SegmentedPropertyTypeCodeMeaning == 'Structure of transition zone of prostate (body structure)']

# %%
metrics_summary_prostatex = temp_df[temp_df["collection_id"]=="prostatex"].groupby('SegmentAlgorithmName').agg(
    mean_dice=('dsc', 'mean'),
    std_dice=('dsc', 'std'),
    min_dice=('dsc', 'min'),
    max_dice=('dsc', 'max'),
    mean_hausdorff95=('hsdff_95', 'mean'),
    std_hausdorff95=('hsdff_95', 'std'),
    min_hausdorff95=('hsdff_95', 'min'),
    max_hausdorff95=('hsdff_95', 'max'),
    mean_ai_volume=("ai_Value", "mean"),
    std_ai_volume=("ai_Value", "std"),
    min_ai_volume=('ai_Value', 'min'),
    max_ai_volume=('ai_Value', 'max'),
    mean_expert_volume=("expert_Value", "mean"),
    std_expert_volume=("expert_Value", "std"),
    min_expert_volume=('expert_Value', 'min'),
    max_expert_volume=('expert_Value', 'max'),
    num_samples=('dsc', 'size')  # Counting number of samples
).round(2).reset_index()

# %%
metrics_summary_prostatex.head()
# Out:
#            SegmentAlgorithmName  mean_dice  std_dice  min_dice  max_dice  \
# 0             monai_prostate158       0.85      0.07      0.59      0.94
# 1  nnunet_prostate_zonal_task05       0.82      0.11      0.35      0.94
#
#    mean_hausdorff95  std_hausdorff95  min_hausdorff95  max_hausdorff95  \
# 0              2.17             1.06             0.35             5.29
# 1              2.96             2.28             0.75            15.83
#
#   mean_ai_volume  std_ai_volume min_ai_volume  max_ai_volume  \
# 0      49.950719          29.56  10.056750000  145.559812000
# 1      54.021906          29.65  12.217750000  149.196125000
#
#   mean_expert_volume  std_expert_volume min_expert_volume max_expert_volume  \
# 0          45.192203              30.09       6.134531000     144.135031000
# 1          45.192203              30.09       6.134531000     144.135031000
#
#    num_samples
# 0           98
# 1           98
